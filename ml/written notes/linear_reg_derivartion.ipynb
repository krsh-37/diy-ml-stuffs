# %% [markdown]
# ![telegram-cloud-photo-size-5-6069088793169872547-y.jpg](attachment:telegram-cloud-photo-size-5-6069088793169872547-y.jpg)

# %% [markdown]
# ![telegram-cloud-photo-size-5-6069088793169872548-y.jpg](attachment:telegram-cloud-photo-size-5-6069088793169872548-y.jpg)
